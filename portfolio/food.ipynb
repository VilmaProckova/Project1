# %%
import pandas as pd
import numpy as np

# %%
df_food = pd.read_csv('indian_food.csv', sep=',')
df_food.head()
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet  prep_time  cook_time flavor_profile   course        state  \
# 0  vegetarian         45         25          sweet  dessert  West Bengal
# 1  vegetarian         80         30          sweet  dessert    Rajasthan
# 2  vegetarian         15         60          sweet  dessert       Punjab
# 3  vegetarian         15         30          sweet  dessert    Rajasthan
# 4  vegetarian         15         40          sweet  dessert  West Bengal
#
#   region
# 0   East
# 1   West
# 2  North
# 3   West
# 4   East

# %%
df_new = (
    df_food
    .assign(
        count_ingredients = lambda df_food: df_food['ingredients'].str.split(',').agg(len)
    )
)
df_new.head()
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet  prep_time  cook_time flavor_profile   course        state  \
# 0  vegetarian         45         25          sweet  dessert  West Bengal
# 1  vegetarian         80         30          sweet  dessert    Rajasthan
# 2  vegetarian         15         60          sweet  dessert       Punjab
# 3  vegetarian         15         30          sweet  dessert    Rajasthan
# 4  vegetarian         15         40          sweet  dessert  West Bengal
#
#   region  count_ingredients
# 0   East                  4
# 1   West                  3
# ...

# %%
df_new['count_ingredients'].sum()
# Out:
# 1136

# %%
list_ingredients = df_new['ingredients'].str.split(',')

# %%
all_ingredients=[]

for i in range(df_new.shape[0]):
    for j in list_ingredients[i]:
        j.strip(),
        all_ingredients.append(j)

# %%
len(all_ingredients)
# Out:
# 1136

# %%
unique_ingredients = list(set(all_ingredients))
len(unique_ingredients)
# Out:
# 426

# %%
stripped = list(map(str.strip, all_ingredients))
lowered = list(map(str.lower, stripped))
uniqed = list(set(lowered))
uniqed.sort()
len(uniqed)
# Out:
# 365

# %%
non_vegan =  ('Beef',
 'Boiled pork',
 'Bombay duck', 
'Chenna',
 'Chhena',
 'Chicken',
 'Chicken thighs', 
'Condensed milk',
 'Cottage cheese',
 'Curd',
 'Dharwadi buffalo milk',
 'Fish',
 'Fish fillet',
 'Fish roe',
'Greek yogurt',
'Lamb', 
'Meat curry powder',
 'Milk',
 'Milk powder', 
'Palak',
 'Paneer', 
'Vermicelli pudding',
'Yoghurt',
 'Yogurt', 
'butter',
 'chenna cheese', 
'chicken',
 'chicken chunks',
 'clarified butter', 
'condensed milk', 
'cottage cheese',
 'cream', 
 'curd', 
 'egg yolks',
 'eggs',
 'fish',
 'fish fillets', 
'fried milk power', 
'ghee',
 'gravy',
'greek yogurt', 
 'honey',
 'heavy cream', 
 'litre milk',
 'lobster',
 'mawa',
 'milk',
 'mutton',
 'nestle cream',
 'palak',
 'pork', 
 'prawns', 
 'reduced milk',
 'skimmed milk powder',
 'skinless chicken breasts',
 'sweetened milk',
 'whipping cream',
 'whole egg',
 'yoghurt',
 'yogurt')

# %%
vegan = (
    
'Aloo',
 'Amaranth leaves',
 'Apricots',
 'Arbi ke patte',
 'Arhar dal',
 'Baby corn',
 'Baby potatoes',
 'Baingan',
 'Baking soda',
 'Banana flower',
 'Basmati rice',
 'Beaten rice flakes',
 'Besan',
 'Besan flour',
 'Biryani masala',
 'Bitter gourd',
 'Black lentils',
 'Bottle gourd',
 'Brinjal',
 'Brown rice',
 'Brown rice flour',
 'Canned coconut milk',
 'Carrot',
 'Carrots',
 'Cashews',
 'Cauliflower',
 'Chana dal',
 'Chickpea flour',
 'Chickpeas',
 'Chole',
 'Cinnamon',
 'Citric acid',
 'Coconut',
 'Coconut milk',
 'Coconut oil',
 'Corn flour',
 'Cucumber',
 'Dry fruits',
 'Fennel',
 'Fermented bamboo shoot',
 'Firm white pumpkin',
 'Flour',
 'Forbidden black rice',
 'Garam masala powder',
 'Glutinous rice',
 'Gobi',
 'Gram flour',
 'Green beans',
 'Green chili paste',
 'Green chilies',
 'Green garlic chutney',
 'Green moong beans',
 'Greens',
 'Jaggery',
 'Jowar flour',
 'Kala chana',
 'Kala masala',
 'Khaman',
 'Khoa',
 'Ladies finger',
  'Lentils',
 'Loaf bread',
 'Maida',
 'Maida flour',
 'Mango',
 'Moong beans',
 'Moong dal',
 'Mushroom',
 'Naan bread',
 'Pav',
 'Pav bhaji masala',
 'Peanuts',
 'Pearl onions',
 'Pigeon peas',
 'Potato',
 'Potatoes',
 'Rava',
 'Raw banana',
 'Raw papaya',
 'Raw peanuts',
 'Raw rice',
 'Red kidney beans',
 'Red pepper',
 'Refined flour',
 'Rice',
 'Rice flakes',
 'Rice flour',
 'Ridge gourd',
 'Rose syrup',
 'Rose water',
 'Sattu',
 'Semolina',
 'Sesame oil',
 'Sev',
 'Sevai',
 'Split pigeon peas',
 'Split urad dal',
 'Sticky rice',
 'Sugar',
 'Sugar',
 'Sugar syrup',
 'Sweet potato',
 'Tea leaves',
 'Thin rice flakes',
 'Tomato',
 'Urad dal',
 'Wheat flour',
 'Whole wheat flour',
 'Whole wheat rava',

 'all purpose flour',
 'almond',
 'almonds',
 'aloo',
 'alum powder',
 'amchur powder',
 'arhar dal',
 'arrowroot powder',
 'atta',
 'avocado oil',
 'axone',
 'baby potatoes',
 'badam',
 'baking powder',
 'baking soda',
 'banana',
 'basmati rice',
 'bay leaf',
 'beans',
 'beetroot',
 'bell pepper',
 'bell peppers',
 'bengal gram flour',
 'besan',
 'bhatura',
 'bhuna chana',
 'biryani masala powder',
 'bitter gourd',
 'black pepper',
 'black salt',
 'black sesame seeds',
 'blend rice',
 'boiled potatoes',
 'bombay rava',
 'boondi',
 'bread crumbs',
 'brinjal',
 'cabbage',
 'capsicum',
 'cardamom',
 'cardamom pods',
 'cardamom powder',
 'carrot',
 'cashew nuts',
 'cashews',
 'cashews and raisins',
 'chana daal',
 'chana dal',
 'chia seed',
 'chickpea flour',
 'chickpeas',
 'chili powder',
 'chilli',
 'chillies',
 'chopped tomatoes',
 'cilantro',
 'cinnamon',
 'cinnamon stick',
 'coconut',
 'coconut flakes',
 'coconut ice',
 'coconut oil',
 'cooked rice',
 'coriander',
 'corn flour',
 'cucumber',
 'curry leaves',
 'dahi',
 'dal',
 'dates',
 'desiccated coconut',
 'dinner rolls',
 'dough',
 'dried fruits',
 'dried mango',
 'dried rose petals',
 'drumstick',
 'drumsticks',
 'dry chilli',
 'dry coconut',
 'dry dates',
 'dry fruits',
 'dry roasted',
 'edible gum',
 'eggplant',
 'elachi',
 'elephant foot yam',
 'falooda sev',
 'fennel',
 'fennel seeds',
 'fenugreek leaves',
 'fenugreek seeds',
 'filling',
 'flour',
 'french beans',
 'fresh coconut',
 'fresh green chilli',
 'fresh green peas',
 'frozen green peas',
 'fry',
 'garam masala',
 'garam masala powder',
 'garlic',
 'garlic powder',
 'ginger',
 'ginger and garlic',
 'ginger powder',
 'gobi',
 'gooseberry',
 'gram flour',
 'grated coconut',
  'green',
 'green bell pepper',
 'green cardamom',
 'green chili',
 'green chilies',
 'green chilli',
 'green chillies',
 'green peas',
 'gur',
 'hot water',
 'idli rice',
 'imli',
 'jaggery',
 'jaggery',
 'jaggery',
 'jaggery syrup',
 'jowar flour',
 'kala jeera',
 'kasuri methi',
 'kewra',
 'khus khus',
 'khus-khus seeds',
 'kitchen lime',
 'kokum',
 'lemon',
 'lemon juice',
 'lentil flour',
 'long beans',
 'low fat',
 'maida flour',
 'makki atta',
 'malai',
 'malvani masala',
 'mango',
 'marinade',
 'masala',
 'mashed potato',
 'masoor dal',
  'methi leaves',
 'mint',
 'mixed nuts',
 'mixed vegetables',
 'molu leaf',
 'mung bean',
 'musk melon seeds',
 'mustard',
 'mustard green',
 'mustard oil',
 'mustard seed',
 'mustard seeds',
 'nigella seeds',
 'nuts',
 'oil',
 'olive oil',
 'onions',
 'orange rind',
 'panch phoran masala',
 'parboiled rice',
 'peanut',
 'peanut oil',
 'pearl millet flour',
 'peas',
 'pistachio',
 'plain flour',
 'pomegranate',
 'poppy seeds',
 'potato',
 'potatoes',
 'potol',
 'powdered sugar',
 'pumpkin flowers',
 'raisins',
 'rapeseed oil',
 'rava',
 'raw rice',
 'red chili',
 'red chilli',
 'red chillies',
 'red food coloring',
 'red onion',
 'reduced milk',
 'refined flour',
 'rice',
 'rice flour',
 'ridge gourd',
 'roasted gram flour',
 'rock salt',
 'rose water',
 'sabudana',
 'saffron',
 'salt',
 'sambar powder',
 'sauce',
 'semolina',
 'sesame',
 'sesame oil',
 'sesame seeds',
 'sev',
 'shimla mirch',
 'sliced almonds',
 'slivered almonds',
 'soaked rice',
 'sooji',
 'sorghum flour',
 'soy sauce',
 'spices',
 'spinach',
 'split urad dal',
 'star anise',
 'steamer',
 'sugar',
 'sugar syrup',
 'sunflower oil',
 'surti papdi',
 'sweet',
 'tamarind',
 'tamarind paste',
 'tandoori masala',
 'tea bags',
 'thick poha',
 'tindora',
 'tomato',
 'tomato paste',
 'tomato sauce',
 'tomatoes',
 'toor dal',
 'turmeric',
 'urad dal',
 'valor papdi',
 'vegetable oil',
 'vinegar',
 'water',
 'watercress',
 'wheat flour',
 'white bread slices',
 'white flour',
 'white sesame seeds',
 'white urad dal',
 'whole red',
 'whole red beans',
 'whole urad dal',
 'whole wheat bread',
 'whole wheat flour',
 'wild mushrooms',
 'wine vinegar',
 'yellow moong daal',
 'yellow mustard',
)

# %%
df_nonvegetarian_meal = df_food.query('diet == "non vegetarian"')
df_nonvegetarian_meal.shape[0]
# Out:
# 29

# %%
df_vegetarian_meal = df_food.query('diet == "vegetarian"')
df_vegetarian_meal.shape[0]
# Out:
# 226

# %%
ingred_first_meal = df_food.loc[0,'ingredients']
first_unstripped_list = ingred_first_meal.split(',')
first_list = [item.strip(" ' ") for item in first_unstripped_list]
first_list
# Out:
# ['Maida flour', 'yogurt', 'oil', 'sugar']

# %%
ingred_second_meal = df_food.loc[5,'ingredients']
second_unstripped_list = ingred_second_meal.split(',')
second_list = [item.strip(" ' ") for item in second_unstripped_list]
second_list
# Out:
# ['Sugar syrup', 'lentil flour']

# %%
df_vegan = (
    df_food
    .assign(
        is_vegan = b
    )
)
df_new.head()
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet  prep_time  cook_time flavor_profile   course        state  \
# 0  vegetarian         45         25          sweet  dessert  West Bengal
# 1  vegetarian         80         30          sweet  dessert    Rajasthan
# 2  vegetarian         15         60          sweet  dessert       Punjab
# 3  vegetarian         15         30          sweet  dessert    Rajasthan
# 4  vegetarian         15         40          sweet  dessert  West Bengal
#
#   region  count_ingredients
# 0   East                  4
# 1   West                  3
# ...

# %%
x = df_food.shape[0]
b = 0
while b < x:
    ingred_meal = df_food.loc[b,'ingredients']
    unstripped_list = ingred_meal.split(',')
    ingred_list = [item.strip(" ' ") for item in unstripped_list]

    for item in ingred_list:
        while item not in non_vegan:
            meal = 'vegan'
            break
        else: 
            meal = 'nonvegan'
            break
    if meal == 'vegan':
        df_food.loc[b,'diet'] = 'vegan'     
        
    b+=1

# %%
df_food.head(10)
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 5          Imarti                          Sugar syrup, lentil flour
# 6          Jalebi  Maida, corn flour, baking soda, vinegar, curd,...
# 7      Kaju katli                     Cashews, ghee, cardamom, sugar
# 8        Kalakand                        Milk, cottage cheese, sugar
# 9           Kheer                    Milk, rice, sugar, dried fruits
#
#          diet  prep_time  cook_time flavor_profile   course          state  \
# 0  vegetarian         45         25          sweet  dessert    West Bengal
# ...

# %%
df_diets = df_food.pivot_table(columns='diet', aggfunc={'diet': 'count'})
df_diets
# Out:
# diet  non vegetarian  vegan  vegetarian
# diet              27    142          86
